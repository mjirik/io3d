# %%
# %pylab inline

import io3d
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Data reader

# %%
dr = io3d.DataReader()
datap = dr.Get3DData('../sample_data/jatra_5mm/', dataplus_format=True)
datap.keys()
# Out:
# ['SeriesNumber',
#  'voxelsize_mm',
#  'SeriesDescription',
#  'dcmfilelist',
#  'ImageComments',
#  'datadir',
#  'data3d',
#  'series_number',
#  'Modality']

# %% [markdown]
# # Visualization

# %%
plt.imshow(datap["data3d"][50,:,:], cmap='gray')
print("pixel spacing = ", datap["voxelsize_mm"])
# Out:
# ('pixel spacing = ', [5.0, 0.75, 0.75])

# %%
datap["data3d"]
# Out:
# array([[[-1024, -1024, -1024, ..., -1024, -1024, -1024],
#         [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#         [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#         ...,
#         [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#         [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#         [-1024, -1024, -1024, ..., -1024, -1024, -1024]],
#
#        [[-1024, -1024, -1024, ..., -1024, -1024, -1024],
#         [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#         [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#         ...,
#         [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#         [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#         [-1024, -1024, -1024, ..., -1024, -1024, -1024]],
#
#        [[-1024, -1024, -1024, ..., -1024, -1024, -1024],
#         [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#         [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#         ...,
#         [-1024, -1024, -1024, ..., -1024, -1024, -1024],
# ...

# %%
import sed3
ed = sed3.show_slices(datap["data3d"], slice_step=10)
