# %%
import json
import matplotlib.pyplot as plt
import numpy as np
from skimage.draw import polygon
import skimage.io
from pathlib import Path
from loguru import logger


class AnnotationTOmask:
    def __init__(self, annotation_file):
        # load dataset
        print('loading annotations ...')
        dataset = json.load(open(annotation_file, 'r'))
        print('annotations loaded!')

        # creating index
        print('creating index...')
        imgToAnns = {ann['image_id']: [] for ann in dataset['annotations']}
        anns =      {ann['id']:       [] for ann in dataset['annotations']}
        for ann in dataset['annotations']:
            imgToAnns[ann['image_id']] += [ann]
            anns[ann['id']] = ann

        imgs      = {im['id']: {} for im in dataset['images']}
        for img in dataset['images']:
            imgs[img['id']] = img

        cats = []
        catToImgs = []
        cats = {cat['id']: [] for cat in dataset['categories']}
        for cat in dataset['categories']:
            cats[cat['id']] = cat
        catToImgs = {cat['id']: [] for cat in dataset['categories']}
        for ann in dataset['annotations']:
            catToImgs[ann['category_id']] += [ann['image_id']]

        print('index created!')

        # create class members
        self.anns = anns
        self.imgToAnns = imgToAnns
        self.catToImgs = catToImgs
        self.imgs = imgs
        self.cats = cats
        self.dataset = dataset


    def getAnnIds(self, imgIds, catIds):
        """
        Get ann ids for given cats from all images
        """
        imgIds = imgIds if type(imgIds) == list else [imgIds]
        catIds = catIds if type(catIds) == list else [catIds]

        if not len(imgIds) == 0:
            anns = sum([self.imgToAnns[imgId] for imgId in imgIds if imgId in self.imgToAnns],[])
        else:
            anns = self.dataset['annotations']
        anns = anns if len(catIds)  == 0 else [ann for ann in anns if ann['category_id'] in catIds]
        ids = [ann['id'] for ann in anns]

        return ids

    def getCatIds(self, catNms=[], catIds=[]):
        """ 
        get integer array of cat ids for given cat names, given cat ids
        """
        if len(catNms) == len(catIds) == 0:
            cats = self.dataset['categories']
        else:
            print('+++++++++++++++++++++')
            cats = self.dataset['categories']
            cats = cats if len(catNms) == 0 else [cat for cat in cats if cat['name']          in catNms]
            cats = cats if len(catIds) == 0 else [cat for cat in cats if cat['id']            in catIds]
        ids = [cat['id'] for cat in cats]
        return ids

    def getImgIds(self, imgIds=[], catIds=[]):
        '''
        return an integer array of img ids for given ids with all given cats
        '''
        ids = set(imgIds)
        for catId in catIds:
            if len(ids) == 0:
                ids = set(self.catToImgs[catId])
            else:
                ids &= set(self.catToImgs[catId])
        return list(ids)

    def loadAnns(self, ids=[]):
        """
        loaded ann objects for integer ids specifying annotations
        """
        if type(ids) == list:
            return [self.anns[id] for id in ids]
        elif type(ids) == int:
            return [self.anns[ids]]

    def loadImgs(self, ids):
        """
        Load loaded img objects with the specified ids.
        """
        return [self.imgs[ids]]

    def getSeg(self, anns):
        """
        get annotations segmentatins
        """
        if len(anns) == 0:
            print('no annotations found')
            return 0

        S = []
        for ann in anns:
            for seg in ann['segmentation']:
                S.append(seg)
        return S

    def segToMask(self, S, h, w ):
         """
         Convert polygon segmentation to binary mask.
           S: polygon segmentation mask, h: target mask height, w: target mask width
         """
         M = np.zeros((h,w))
         for s in S:
             N = len(s)
             rr, cc = polygon(np.array(s[1:N:2]), np.array(s[0:N:2])) # (y, x)
             M[rr, cc] = 1
         return M


def coco_to_mask(coco_filename, output_dir, organ, voxelsize_mm=None, output_type="JPG", show=False, name_prefix="MaskOfPig_"):
    """
    :param coco_filename: coco_filename must include not only name of Coco file, but also it`s full direction (location) in your PC
    :param output_dir: is used for controll output direction (location) in your PC
    :param organ: name of segmentation part rom what we want have mask ""
    :param voxelsize_mm:
    :param output_type: type of "Save fail" of our program| results]
    :param show:
    :return:
    """
    #file_path = 'task_cell track 20200226-dii-30las-2pre1-2020_10_26_13_28_36-coco 1.0/annotations/instances_default.json'

    file_path = coco_filename
    import datetime
    t0 = datetime.datetime.now()
    cv_an = AnnotationTOmask(file_path)
    t1 = datetime.datetime.now()
    cv_an1=cv_an.getImgIds()
    t2 = datetime.datetime.now()
    logger.debug(f"{t1 - t0}, {t2 - t1}")
    logger.debug('getImgIds', cv_an1)
    # extract the region we want to mask ( Right Kidny,  Liver)

    #catIds = cv_an.getCatIds(catNms=['cell'])
    catIds = cv_an.getCatIds(catNms=[organ])
    #catIds = cv_an.getCatIds(catNms=['Liver'])
    #catIds = cv_an.getCatIds(catNms=['Left Kidney'])

    logger.debug('catIds', catIds)
    imgIds = cv_an.getImgIds(catIds=catIds)
    if len(imgIds) == 0:
        logger.warning(f"Label '{organ}' not found.")
    logger.debug(f'imgIds={imgIds}')
    Path(output_dir).mkdir(parents=True, exist_ok=True)

    #TODO allow storing into one file
    #  imgName = cv_an.dataset['images'][0]
    #  M = np.zeros([imgName['width'], imgName['height'],len(cv_an["images"])])
    #  ...

    # create empty files
    for imgName in cv_an.dataset['images']:
        logger.debug(f'imgName={imgName}')
        M = np.zeros([imgName['width'], imgName['height']])
        image_path = Path(output_dir) / (name_prefix+Path(imgName['file_name']).name+'.'+output_type)
        logger.debug(f"image_path={image_path}")
        skimage.io.imsave(image_path, np.uint8(M), check_contrast=False)
        # plt.imsave(image_path, np.uint8(M), cmap = 'gray')

    # rewrite images with label
    for im in imgIds:
        logger.debug(f"iM{im}")
        imgName = cv_an.loadImgs(im)[0]
        anns_ids = cv_an.getAnnIds(imgIds=imgName['id'], catIds=catIds)
        anns = cv_an.loadAnns(anns_ids)
        S = cv_an.getSeg(anns)
        M = cv_an.segToMask(S, imgName['width'], imgName['height']) * 255
        if show:
            plt.figure()
            plt.imshow(M)
            plt.show()
            plt.close()
        # image_path = Path(output_dir) / ('MaskOfPIG_'+str(imgName['file_name'])+'.'+output_type)
        image_path = Path(output_dir) / (name_prefix+Path(imgName['file_name']).name+'.'+output_type)
        logger.debug(image_path)
        un = np.unique(M)
        if len(un) < 2:
            logger.warning(f"No data found in annotation {imgName['file_name']}")
        skimage.io.imsave(image_path, np.uint8(M), check_contrast=False)
        plt.imsave(image_path, np.uint8(M), cmap='gray')

    logger.debug('Done')

# %%
Coco_Path="F:/PigProject/pig28/annotations/Pig28.json"
Output_Path="F:/PigProject/pig28/annotations/PNG"
organ="Left Kidney"
coco_to_mask1=coco_to_mask(Coco_Path, Output_Path, organ, voxelsize_mm=None, output_type="PNG", show=False, name_prefix="MaskOfPig_")
# Out:
# 2022-09-11 18:22:43.660 | DEBUG    | __main__:coco_to_mask:152 - 0:00:00.052858, 0:00:00
# 2022-09-11 18:22:43.661 | DEBUG    | __main__:coco_to_mask:153 - getImgIds
# 2022-09-11 18:22:43.661 | DEBUG    | __main__:coco_to_mask:161 - catIds
# 2022-09-11 18:22:43.662 | DEBUG    | __main__:coco_to_mask:165 - imgIds=[598, 599, 600, 601, 602, 603, 604, 605, 606, 607, 608, 609, 610, 611, 612, 613, 614, 615, 616, 617, 618, 619, 620, 621, 622, 623, 624, 625, 626, 627, 628, 629, 630, 631, 632, 633, 634, 635, 636, 637, 638, 639, 640, 641, 642, 643, 644, 645, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 382, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 395, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405]
# 2022-09-11 18:22:43.663 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 1, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_01018.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:43.665 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_01018.jpg.PNG
# loading annotations ...
# annotations loaded!
# creating index...
# index created!
# +++++++++++++++++++++
# 2022-09-11 18:22:44.017 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 2, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_01017.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.018 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_01017.jpg.PNG
# 2022-09-11 18:22:44.023 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 3, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_01016.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.024 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_01016.jpg.PNG
# 2022-09-11 18:22:44.145 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 4, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_01015.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.146 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_01015.jpg.PNG
# 2022-09-11 18:22:44.153 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 5, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_01014.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.154 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_01014.jpg.PNG
# 2022-09-11 18:22:44.160 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 6, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_01013.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.161 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_01013.jpg.PNG
# 2022-09-11 18:22:44.167 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 7, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_01012.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.168 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_01012.jpg.PNG
# 2022-09-11 18:22:44.177 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 8, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_01011.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.178 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_01011.jpg.PNG
# 2022-09-11 18:22:44.185 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 9, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_01010.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.187 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_01010.jpg.PNG
# 2022-09-11 18:22:44.195 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 10, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_01009.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.196 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_01009.jpg.PNG
# 2022-09-11 18:22:44.205 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 11, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_01008.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.209 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_01008.jpg.PNG
# 2022-09-11 18:22:44.216 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_01007.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.218 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_01007.jpg.PNG
# 2022-09-11 18:22:44.228 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 13, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_01006.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.229 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_01006.jpg.PNG
# 2022-09-11 18:22:44.235 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 14, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_01005.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.236 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_01005.jpg.PNG
# 2022-09-11 18:22:44.263 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 15, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_01004.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.265 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_01004.jpg.PNG
# 2022-09-11 18:22:44.286 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 16, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_01003.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.288 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_01003.jpg.PNG
# 2022-09-11 18:22:44.320 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 17, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_01002.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.321 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_01002.jpg.PNG
# 2022-09-11 18:22:44.326 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 18, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_01001.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.327 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_01001.jpg.PNG
# 2022-09-11 18:22:44.336 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 19, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_01000.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.337 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_01000.jpg.PNG
# 2022-09-11 18:22:44.343 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 20, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00999.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.344 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00999.jpg.PNG
# 2022-09-11 18:22:44.384 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 21, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00998.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.385 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00998.jpg.PNG
# 2022-09-11 18:22:44.391 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 22, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00997.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.393 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00997.jpg.PNG
# 2022-09-11 18:22:44.421 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 23, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00996.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.422 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00996.jpg.PNG
# 2022-09-11 18:22:44.465 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 24, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00995.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.468 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00995.jpg.PNG
# 2022-09-11 18:22:44.474 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 25, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00994.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.475 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00994.jpg.PNG
# 2022-09-11 18:22:44.497 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 26, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00993.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.501 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00993.jpg.PNG
# 2022-09-11 18:22:44.509 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 27, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00992.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.510 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00992.jpg.PNG
# 2022-09-11 18:22:44.517 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 28, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00991.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.518 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00991.jpg.PNG
# 2022-09-11 18:22:44.555 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 29, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00990.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.556 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00990.jpg.PNG
# 2022-09-11 18:22:44.562 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 30, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00989.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.563 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00989.jpg.PNG
# 2022-09-11 18:22:44.572 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 31, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00988.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.573 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00988.jpg.PNG
# 2022-09-11 18:22:44.614 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 32, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00987.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.616 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00987.jpg.PNG
# 2022-09-11 18:22:44.649 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 33, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00986.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.650 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00986.jpg.PNG
# 2022-09-11 18:22:44.680 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 34, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00985.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.682 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00985.jpg.PNG
# 2022-09-11 18:22:44.752 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 35, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00984.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.753 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00984.jpg.PNG
# 2022-09-11 18:22:44.778 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 36, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00983.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.779 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00983.jpg.PNG
# 2022-09-11 18:22:44.787 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 37, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00982.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.789 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00982.jpg.PNG
# 2022-09-11 18:22:44.819 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 38, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00981.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.820 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00981.jpg.PNG
# 2022-09-11 18:22:44.826 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 39, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00980.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.827 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00980.jpg.PNG
# 2022-09-11 18:22:44.837 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 40, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00979.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.838 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00979.jpg.PNG
# 2022-09-11 18:22:44.871 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 41, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00978.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.872 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00978.jpg.PNG
# 2022-09-11 18:22:44.916 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 42, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00977.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.917 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00977.jpg.PNG
# 2022-09-11 18:22:44.945 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 43, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00976.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.947 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00976.jpg.PNG
# 2022-09-11 18:22:44.954 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 44, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00975.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.955 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00975.jpg.PNG
# 2022-09-11 18:22:44.992 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 45, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00974.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:44.994 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00974.jpg.PNG
# 2022-09-11 18:22:45.000 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 46, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00973.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.001 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00973.jpg.PNG
# 2022-09-11 18:22:45.007 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 47, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00972.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.009 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00972.jpg.PNG
# 2022-09-11 18:22:45.019 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 48, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00971.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.021 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00971.jpg.PNG
# 2022-09-11 18:22:45.030 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 49, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00970.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.032 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00970.jpg.PNG
# 2022-09-11 18:22:45.039 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 50, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00969.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.041 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00969.jpg.PNG
# 2022-09-11 18:22:45.054 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 51, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00968.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.056 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00968.jpg.PNG
# 2022-09-11 18:22:45.061 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 52, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00967.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.063 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00967.jpg.PNG
# 2022-09-11 18:22:45.100 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 53, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00966.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.102 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00966.jpg.PNG
# 2022-09-11 18:22:45.110 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 54, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00965.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.111 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00965.jpg.PNG
# 2022-09-11 18:22:45.118 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 55, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00964.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.119 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00964.jpg.PNG
# 2022-09-11 18:22:45.125 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 56, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00963.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.127 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00963.jpg.PNG
# 2022-09-11 18:22:45.138 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 57, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00962.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.139 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00962.jpg.PNG
# 2022-09-11 18:22:45.145 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 58, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00961.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.146 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00961.jpg.PNG
# 2022-09-11 18:22:45.153 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 59, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00960.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.154 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00960.jpg.PNG
# 2022-09-11 18:22:45.162 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 60, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00959.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.163 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00959.jpg.PNG
# 2022-09-11 18:22:45.171 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 61, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00958.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.172 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00958.jpg.PNG
# 2022-09-11 18:22:45.179 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 62, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00957.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.181 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00957.jpg.PNG
# 2022-09-11 18:22:45.188 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 63, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00956.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.189 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00956.jpg.PNG
# 2022-09-11 18:22:45.194 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 64, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00955.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.196 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00955.jpg.PNG
# 2022-09-11 18:22:45.204 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 65, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00954.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.205 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00954.jpg.PNG
# 2022-09-11 18:22:45.212 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 66, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00953.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.213 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00953.jpg.PNG
# 2022-09-11 18:22:45.221 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 67, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00952.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.222 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00952.jpg.PNG
# 2022-09-11 18:22:45.228 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 68, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00951.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.229 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00951.jpg.PNG
# 2022-09-11 18:22:45.240 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 69, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00950.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.241 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00950.jpg.PNG
# 2022-09-11 18:22:45.249 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 70, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00949.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.252 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00949.jpg.PNG
# 2022-09-11 18:22:45.259 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 71, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00948.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.261 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00948.jpg.PNG
# 2022-09-11 18:22:45.270 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 72, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00947.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.272 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00947.jpg.PNG
# 2022-09-11 18:22:45.279 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 73, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00946.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.280 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00946.jpg.PNG
# 2022-09-11 18:22:45.290 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 74, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00945.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.291 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00945.jpg.PNG
# 2022-09-11 18:22:45.297 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 75, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00944.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.301 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00944.jpg.PNG
# 2022-09-11 18:22:45.308 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 76, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00943.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.310 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00943.jpg.PNG
# 2022-09-11 18:22:45.319 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 77, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00942.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.322 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00942.jpg.PNG
# 2022-09-11 18:22:45.327 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 78, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00941.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.329 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00941.jpg.PNG
# 2022-09-11 18:22:45.343 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 79, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00940.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.345 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00940.jpg.PNG
# 2022-09-11 18:22:45.355 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 80, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00939.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.356 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00939.jpg.PNG
# 2022-09-11 18:22:45.362 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 81, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00938.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.363 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00938.jpg.PNG
# 2022-09-11 18:22:45.373 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 82, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00937.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.374 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00937.jpg.PNG
# 2022-09-11 18:22:45.380 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 83, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00936.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.384 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00936.jpg.PNG
# 2022-09-11 18:22:45.390 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 84, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00935.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.391 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00935.jpg.PNG
# 2022-09-11 18:22:45.397 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 85, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00934.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.400 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00934.jpg.PNG
# 2022-09-11 18:22:45.407 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 86, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00933.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.408 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00933.jpg.PNG
# 2022-09-11 18:22:45.416 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 87, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00869.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.417 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00869.jpg.PNG
# 2022-09-11 18:22:45.423 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 88, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00868.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.425 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00868.jpg.PNG
# 2022-09-11 18:22:45.431 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 89, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00867.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.432 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00867.jpg.PNG
# 2022-09-11 18:22:45.438 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 90, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00866.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.439 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00866.jpg.PNG
# 2022-09-11 18:22:45.445 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 91, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00865.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.446 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00865.jpg.PNG
# 2022-09-11 18:22:45.452 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 92, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00864.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.454 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00864.jpg.PNG
# 2022-09-11 18:22:45.459 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 93, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00863.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.460 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00863.jpg.PNG
# 2022-09-11 18:22:45.465 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 94, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00862.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.466 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00862.jpg.PNG
# 2022-09-11 18:22:45.471 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 95, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00861.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.472 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00861.jpg.PNG
# 2022-09-11 18:22:45.478 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 96, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00860.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.481 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00860.jpg.PNG
# 2022-09-11 18:22:45.491 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 97, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00859.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.492 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00859.jpg.PNG
# 2022-09-11 18:22:45.497 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 98, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00858.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.500 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00858.jpg.PNG
# 2022-09-11 18:22:45.509 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 99, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00857.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.511 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00857.jpg.PNG
# 2022-09-11 18:22:45.518 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 100, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00856.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.520 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00856.jpg.PNG
# 2022-09-11 18:22:45.525 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 101, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00855.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.526 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00855.jpg.PNG
# 2022-09-11 18:22:45.532 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 102, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00854.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.535 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00854.jpg.PNG
# 2022-09-11 18:22:45.545 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 103, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00853.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.546 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00853.jpg.PNG
# 2022-09-11 18:22:45.555 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 104, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00852.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.556 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00852.jpg.PNG
# 2022-09-11 18:22:45.561 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 105, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00851.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.562 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00851.jpg.PNG
# 2022-09-11 18:22:45.569 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 106, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00850.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.575 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00850.jpg.PNG
# 2022-09-11 18:22:45.587 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 107, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00849.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.588 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00849.jpg.PNG
# 2022-09-11 18:22:45.593 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 108, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00848.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.595 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00848.jpg.PNG
# 2022-09-11 18:22:45.602 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 109, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00847.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.603 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00847.jpg.PNG
# 2022-09-11 18:22:45.613 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 110, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00846.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.616 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00846.jpg.PNG
# 2022-09-11 18:22:45.623 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 111, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00845.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.625 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00845.jpg.PNG
# 2022-09-11 18:22:45.630 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 112, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00844.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.633 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00844.jpg.PNG
# 2022-09-11 18:22:45.639 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 113, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00843.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.640 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00843.jpg.PNG
# 2022-09-11 18:22:45.652 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 114, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00842.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.654 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00842.jpg.PNG
# 2022-09-11 18:22:45.659 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 115, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00841.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.660 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00841.jpg.PNG
# 2022-09-11 18:22:45.668 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 116, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00840.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.669 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00840.jpg.PNG
# 2022-09-11 18:22:45.678 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 117, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00839.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.680 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00839.jpg.PNG
# 2022-09-11 18:22:45.687 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 118, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00838.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.689 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00838.jpg.PNG
# 2022-09-11 18:22:45.694 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 119, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00837.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.696 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00837.jpg.PNG
# 2022-09-11 18:22:45.703 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 120, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00836.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.704 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00836.jpg.PNG
# 2022-09-11 18:22:45.710 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 121, 'width': 512, 'height': 512, 'file_name': 'Tx028D_Ven/Tx028D_Vensoubor_00835.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2022-09-11 18:22:45.712 | DEBUG    | __main__:coco_to_mask:178 - image_path=F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00835.jpg.PNG
# ...
# 2022-09-11 18:22:53.615 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00612.jpg.PNG
# 2022-09-11 18:22:53.629 | DEBUG    | __main__:coco_to_mask:184 - iM640
# 2022-09-11 18:22:53.635 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00611.jpg.PNG
# 2022-09-11 18:22:53.661 | DEBUG    | __main__:coco_to_mask:184 - iM641
# 2022-09-11 18:22:53.665 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00610.jpg.PNG
# 2022-09-11 18:22:53.678 | DEBUG    | __main__:coco_to_mask:184 - iM642
# 2022-09-11 18:22:53.683 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00609.jpg.PNG
# 2022-09-11 18:22:53.695 | DEBUG    | __main__:coco_to_mask:184 - iM643
# 2022-09-11 18:22:53.699 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00608.jpg.PNG
# 2022-09-11 18:22:53.711 | DEBUG    | __main__:coco_to_mask:184 - iM644
# 2022-09-11 18:22:53.716 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00607.jpg.PNG
# 2022-09-11 18:22:53.728 | DEBUG    | __main__:coco_to_mask:184 - iM645
# 2022-09-11 18:22:53.732 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00606.jpg.PNG
# 2022-09-11 18:22:53.744 | DEBUG    | __main__:coco_to_mask:184 - iM275
# 2022-09-11 18:22:53.748 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00681.jpg.PNG
# 2022-09-11 18:22:53.758 | DEBUG    | __main__:coco_to_mask:184 - iM276
# 2022-09-11 18:22:53.761 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00680.jpg.PNG
# 2022-09-11 18:22:53.771 | DEBUG    | __main__:coco_to_mask:184 - iM277
# 2022-09-11 18:22:53.774 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00679.jpg.PNG
# 2022-09-11 18:22:53.785 | DEBUG    | __main__:coco_to_mask:184 - iM278
# 2022-09-11 18:22:53.788 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00678.jpg.PNG
# 2022-09-11 18:22:53.803 | DEBUG    | __main__:coco_to_mask:184 - iM279
# 2022-09-11 18:22:53.806 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00677.jpg.PNG
# 2022-09-11 18:22:53.818 | DEBUG    | __main__:coco_to_mask:184 - iM280
# 2022-09-11 18:22:53.820 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00676.jpg.PNG
# 2022-09-11 18:22:53.837 | DEBUG    | __main__:coco_to_mask:184 - iM281
# 2022-09-11 18:22:53.839 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00675.jpg.PNG
# 2022-09-11 18:22:53.851 | DEBUG    | __main__:coco_to_mask:184 - iM282
# 2022-09-11 18:22:53.854 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00674.jpg.PNG
# 2022-09-11 18:22:53.867 | DEBUG    | __main__:coco_to_mask:184 - iM283
# 2022-09-11 18:22:53.870 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00673.jpg.PNG
# 2022-09-11 18:22:53.882 | DEBUG    | __main__:coco_to_mask:184 - iM284
# 2022-09-11 18:22:53.890 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00672.jpg.PNG
# 2022-09-11 18:22:53.905 | DEBUG    | __main__:coco_to_mask:184 - iM285
# 2022-09-11 18:22:53.908 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00671.jpg.PNG
# 2022-09-11 18:22:53.921 | DEBUG    | __main__:coco_to_mask:184 - iM286
# 2022-09-11 18:22:53.924 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00670.jpg.PNG
# 2022-09-11 18:22:53.938 | DEBUG    | __main__:coco_to_mask:184 - iM287
# 2022-09-11 18:22:53.942 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00669.jpg.PNG
# 2022-09-11 18:22:53.956 | DEBUG    | __main__:coco_to_mask:184 - iM288
# 2022-09-11 18:22:53.960 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00668.jpg.PNG
# 2022-09-11 18:22:53.983 | DEBUG    | __main__:coco_to_mask:184 - iM289
# 2022-09-11 18:22:53.987 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00667.jpg.PNG
# 2022-09-11 18:22:54.000 | DEBUG    | __main__:coco_to_mask:184 - iM290
# 2022-09-11 18:22:54.004 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00666.jpg.PNG
# 2022-09-11 18:22:54.021 | DEBUG    | __main__:coco_to_mask:184 - iM291
# 2022-09-11 18:22:54.026 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00665.jpg.PNG
# 2022-09-11 18:22:54.042 | DEBUG    | __main__:coco_to_mask:184 - iM292
# 2022-09-11 18:22:54.047 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00664.jpg.PNG
# 2022-09-11 18:22:54.066 | DEBUG    | __main__:coco_to_mask:184 - iM293
# 2022-09-11 18:22:54.070 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00663.jpg.PNG
# 2022-09-11 18:22:54.087 | DEBUG    | __main__:coco_to_mask:184 - iM294
# 2022-09-11 18:22:54.092 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00662.jpg.PNG
# 2022-09-11 18:22:54.108 | DEBUG    | __main__:coco_to_mask:184 - iM295
# 2022-09-11 18:22:54.122 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00661.jpg.PNG
# 2022-09-11 18:22:54.138 | DEBUG    | __main__:coco_to_mask:184 - iM296
# 2022-09-11 18:22:54.142 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00660.jpg.PNG
# 2022-09-11 18:22:54.168 | DEBUG    | __main__:coco_to_mask:184 - iM297
# 2022-09-11 18:22:54.172 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00659.jpg.PNG
# 2022-09-11 18:22:54.189 | DEBUG    | __main__:coco_to_mask:184 - iM298
# 2022-09-11 18:22:54.194 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00658.jpg.PNG
# 2022-09-11 18:22:54.214 | DEBUG    | __main__:coco_to_mask:184 - iM299
# 2022-09-11 18:22:54.220 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00657.jpg.PNG
# 2022-09-11 18:22:54.236 | DEBUG    | __main__:coco_to_mask:184 - iM300
# 2022-09-11 18:22:54.240 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00656.jpg.PNG
# 2022-09-11 18:22:54.333 | DEBUG    | __main__:coco_to_mask:184 - iM301
# 2022-09-11 18:22:54.336 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00655.jpg.PNG
# 2022-09-11 18:22:54.350 | DEBUG    | __main__:coco_to_mask:184 - iM302
# 2022-09-11 18:22:54.354 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00654.jpg.PNG
# 2022-09-11 18:22:54.371 | DEBUG    | __main__:coco_to_mask:184 - iM303
# 2022-09-11 18:22:54.377 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00605.jpg.PNG
# 2022-09-11 18:22:54.391 | DEBUG    | __main__:coco_to_mask:184 - iM304
# 2022-09-11 18:22:54.399 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00604.jpg.PNG
# 2022-09-11 18:22:54.413 | DEBUG    | __main__:coco_to_mask:184 - iM305
# 2022-09-11 18:22:54.419 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00603.jpg.PNG
# 2022-09-11 18:22:54.434 | DEBUG    | __main__:coco_to_mask:184 - iM306
# 2022-09-11 18:22:54.440 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00602.jpg.PNG
# 2022-09-11 18:22:54.474 | DEBUG    | __main__:coco_to_mask:184 - iM307
# 2022-09-11 18:22:54.481 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00601.jpg.PNG
# 2022-09-11 18:22:54.503 | DEBUG    | __main__:coco_to_mask:184 - iM308
# 2022-09-11 18:22:54.508 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00600.jpg.PNG
# 2022-09-11 18:22:54.525 | DEBUG    | __main__:coco_to_mask:184 - iM309
# 2022-09-11 18:22:54.528 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00599.jpg.PNG
# 2022-09-11 18:22:54.556 | DEBUG    | __main__:coco_to_mask:184 - iM310
# 2022-09-11 18:22:54.559 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00598.jpg.PNG
# 2022-09-11 18:22:54.571 | DEBUG    | __main__:coco_to_mask:184 - iM311
# 2022-09-11 18:22:54.576 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00597.jpg.PNG
# 2022-09-11 18:22:54.588 | DEBUG    | __main__:coco_to_mask:184 - iM312
# 2022-09-11 18:22:54.591 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00596.jpg.PNG
# 2022-09-11 18:22:54.603 | DEBUG    | __main__:coco_to_mask:184 - iM313
# 2022-09-11 18:22:54.607 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00595.jpg.PNG
# 2022-09-11 18:22:54.644 | DEBUG    | __main__:coco_to_mask:184 - iM314
# 2022-09-11 18:22:54.649 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00594.jpg.PNG
# 2022-09-11 18:22:54.661 | DEBUG    | __main__:coco_to_mask:184 - iM315
# 2022-09-11 18:22:54.665 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00593.jpg.PNG
# 2022-09-11 18:22:54.677 | DEBUG    | __main__:coco_to_mask:184 - iM316
# 2022-09-11 18:22:54.681 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00592.jpg.PNG
# 2022-09-11 18:22:54.693 | DEBUG    | __main__:coco_to_mask:184 - iM317
# 2022-09-11 18:22:54.698 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00591.jpg.PNG
# 2022-09-11 18:22:54.710 | DEBUG    | __main__:coco_to_mask:184 - iM318
# 2022-09-11 18:22:54.714 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00590.jpg.PNG
# 2022-09-11 18:22:54.726 | DEBUG    | __main__:coco_to_mask:184 - iM382
# 2022-09-11 18:22:54.730 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00589.jpg.PNG
# 2022-09-11 18:22:54.742 | DEBUG    | __main__:coco_to_mask:184 - iM383
# 2022-09-11 18:22:54.747 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00588.jpg.PNG
# 2022-09-11 18:22:54.759 | DEBUG    | __main__:coco_to_mask:184 - iM384
# 2022-09-11 18:22:54.763 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00587.jpg.PNG
# 2022-09-11 18:22:54.779 | DEBUG    | __main__:coco_to_mask:184 - iM385
# 2022-09-11 18:22:54.784 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00586.jpg.PNG
# 2022-09-11 18:22:54.798 | DEBUG    | __main__:coco_to_mask:184 - iM386
# 2022-09-11 18:22:54.803 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00585.jpg.PNG
# 2022-09-11 18:22:54.820 | DEBUG    | __main__:coco_to_mask:184 - iM387
# 2022-09-11 18:22:54.825 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00584.jpg.PNG
# 2022-09-11 18:22:54.839 | DEBUG    | __main__:coco_to_mask:184 - iM388
# 2022-09-11 18:22:54.843 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00583.jpg.PNG
# 2022-09-11 18:22:54.857 | DEBUG    | __main__:coco_to_mask:184 - iM389
# 2022-09-11 18:22:54.861 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00582.jpg.PNG
# 2022-09-11 18:22:54.875 | DEBUG    | __main__:coco_to_mask:184 - iM390
# 2022-09-11 18:22:54.878 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00581.jpg.PNG
# 2022-09-11 18:22:54.893 | DEBUG    | __main__:coco_to_mask:184 - iM391
# 2022-09-11 18:22:54.898 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00580.jpg.PNG
# 2022-09-11 18:22:54.910 | DEBUG    | __main__:coco_to_mask:184 - iM392
# 2022-09-11 18:22:54.914 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00579.jpg.PNG
# 2022-09-11 18:22:54.928 | DEBUG    | __main__:coco_to_mask:184 - iM393
# 2022-09-11 18:22:54.933 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00578.jpg.PNG
# 2022-09-11 18:22:54.949 | DEBUG    | __main__:coco_to_mask:184 - iM394
# 2022-09-11 18:22:54.954 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00577.jpg.PNG
# 2022-09-11 18:22:54.967 | DEBUG    | __main__:coco_to_mask:184 - iM395
# 2022-09-11 18:22:54.974 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00576.jpg.PNG
# 2022-09-11 18:22:54.988 | DEBUG    | __main__:coco_to_mask:184 - iM396
# 2022-09-11 18:22:54.992 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00575.jpg.PNG
# 2022-09-11 18:22:55.006 | DEBUG    | __main__:coco_to_mask:184 - iM397
# 2022-09-11 18:22:55.009 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00574.jpg.PNG
# 2022-09-11 18:22:55.026 | DEBUG    | __main__:coco_to_mask:184 - iM398
# 2022-09-11 18:22:55.030 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00573.jpg.PNG
# 2022-09-11 18:22:55.042 | DEBUG    | __main__:coco_to_mask:184 - iM399
# 2022-09-11 18:22:55.046 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00572.jpg.PNG
# 2022-09-11 18:22:55.058 | DEBUG    | __main__:coco_to_mask:184 - iM400
# 2022-09-11 18:22:55.063 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00571.jpg.PNG
# 2022-09-11 18:22:55.076 | DEBUG    | __main__:coco_to_mask:184 - iM401
# 2022-09-11 18:22:55.079 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00570.jpg.PNG
# 2022-09-11 18:22:55.091 | DEBUG    | __main__:coco_to_mask:184 - iM402
# 2022-09-11 18:22:55.095 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00569.jpg.PNG
# 2022-09-11 18:22:55.106 | DEBUG    | __main__:coco_to_mask:184 - iM403
# 2022-09-11 18:22:55.110 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00568.jpg.PNG
# 2022-09-11 18:22:55.121 | DEBUG    | __main__:coco_to_mask:184 - iM404
# 2022-09-11 18:22:55.125 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00567.jpg.PNG
# 2022-09-11 18:22:55.144 | DEBUG    | __main__:coco_to_mask:184 - iM405
# 2022-09-11 18:22:55.148 | DEBUG    | __main__:coco_to_mask:197 - F:\PigProject\pig28\annotations\PNG\MaskOfPig_Tx028D_Vensoubor_00566.jpg.PNG
# 2022-09-11 18:22:55.160 | DEBUG    | __main__:coco_to_mask:204 - Done
